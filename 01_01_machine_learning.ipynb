# %% [markdown]
# # ML

# %% [markdown]
# ## Get Data from DB

# %%
import couchdb
import pandas as pd
import numpy as np

# %%
username = 'admin'
password = 'password'
db_url = 'http://127.0.0.1:5984/'
db_auth_url = f'http://{username}:{password}@127.0.0.1:5984/'

# %%
import couchdb
couch = couchdb.Server(db_auth_url)
couch
# Out:
# <Server 'http://127.0.0.1:5984/'>

# %%
# Connect do databases:
db_gdp = couch['gdp']
db_nat = couch['natural_disasters']

# %% [markdown]
# ### Natural Disasters Data

# %%
# Query natural disasters table
rows = db_nat.view('_all_docs', include_docs=True)
data = [row['doc'] for row in rows]
df_nat = pd.DataFrame(data)

# %%
# TEMPORARY
df_nat = df_nat.drop(['_id', '_rev'], axis=1)
df_nat.head()
# Out:
#       country iso_country  year     type           group event_name  \
# 0  Bangladesh         BGD  1961    Storm  Meteorological        NaN
# 1  Bangladesh         BGD  1961    Storm  Meteorological        NaN
# 2  Bangladesh         BGD  1961    Storm  Meteorological        NaN
# 3      Belize         BLZ  1961    Storm  Meteorological     Hattie
# 4      Canada         CAN  1961  Drought  Climatological        NaN
#
#              region continent  total_deaths  total_affected  duration
# 0     Southern Asia      Asia       11000.0            -1.0         0
# 1     Southern Asia      Asia          -1.0            -1.0         0
# 2     Southern Asia      Asia         266.0            -1.0        30
# 3   Central America  Americas         275.0            -1.0         1
# 4  Northern America  Americas          -1.0            -1.0       364

# %%
ml_features = ['type', 'group', 'total_deaths', 'total_affected']

# %% [markdown]
# Preparing Dataset

# %%
df_nat['total_deaths'].replace(-1, np.nan, inplace=True)
df_nat['total_affected'].replace(-1, np.nan, inplace=True)

# %%
df_nat = df_nat.dropna(subset=ml_features)
df_nat.shape[0]
# Out:
# 7455

# %% [markdown]
# ### Country GDP's Data

# %%
# Query gdp table
rows = db_gdp.view('_all_docs', include_docs=True)
data = [row['doc'] for row in rows]
df_gdp = pd.DataFrame(data)

# %%
# TEMPORARY
df_gdp = df_gdp.drop(['_id', '_rev'], axis=1)
df_gdp.head()
# Out:
#   iso_country     gdp_value  year
# 0         ZAF  3.879346e+11  2019
# 1         ZAF  4.048421e+11  2018
# 2         ZAF  3.814488e+11  2017
# 3         ZAF  3.235855e+11  2016
# 4         ZAF  3.467098e+11  2015

# %% [markdown]
# ## Combine Data

# %%
df = df_nat.copy()

for index, row in df.iterrows():
    iso = row['iso_country']
    year = row['year']

    gdps_by_year = df_gdp.loc[(df_gdp['iso_country'] == iso)].set_index('year')['gdp_value']

    gdp_m_1     = gdps_by_year[year-1]  if year-1   in gdps_by_year else np.nan
    gdp         = gdps_by_year[year]    if year     in gdps_by_year else np.nan
    gdp_p_1     = gdps_by_year[year+1]  if year+1   in gdps_by_year else np.nan
    gdp_p_2     = gdps_by_year[year+2]  if year+2   in gdps_by_year else np.nan
    gdp_p_3     = gdps_by_year[year+3]  if year+3   in gdps_by_year else np.nan

    gdp_change = ((gdp_p_1 + gdp_p_2 + gdp_p_3) / 3) / ((gdp_m_1 + gdp) / 2)
    
    df.at[index, 'gdp-1']  = gdp_m_1
    df.at[index, 'gdp']    = gdp
    df.at[index, 'gdp+1']  = gdp_p_1
    df.at[index, 'gdp+2']  = gdp_p_2
    df.at[index, 'gdp+3']  = gdp_p_3

    # adding gdp_change resembling the relative difference between the average of before and after the disaster
    df.at[index, 'gdp_change'] = gdp_change

df.head()
# Out:
#        country iso_country  year               type           group  \
# 8    Hong Kong         HKG  1961              Storm  Meteorological
# 12     Albania         ALB  1962         Earthquake     Geophysical
# 14    Colombia         COL  1962         Earthquake     Geophysical
# 22  Bangladesh         BGD  1963              Storm  Meteorological
# 26  Costa Rica         CRI  1963  Volcanic activity     Geophysical
#
#    event_name           region continent  total_deaths  total_affected  \
# 8        Olga     Eastern Asia      Asia           7.0          1171.0
# 12        NaN  Southern Europe    Europe          15.0           154.0
# 14        NaN    South America  Americas          47.0           300.0
# 22        NaN    Southern Asia      Asia       22000.0       1000000.0
# 26        NaN  Central America  Americas          15.0          5200.0
#
#     duration         gdp-1           gdp         gdp+1         gdp+2  \
# 8          0  1.320797e+09  1.383682e+09  1.612346e+09  1.935298e+09
# 12         0           NaN           NaN           NaN           NaN
# 14         0  4.540448e+09  4.955544e+09  4.836167e+09  5.973367e+09
# 22         0  5.081413e+09  5.319458e+09  5.386055e+09  5.906637e+09
# 26         0  4.791808e+08  5.119021e+08  5.425784e+08  5.929812e+08
#
#            gdp+3  gdp_change
# 8   2.206466e+09    1.418416
# 12           NaN         NaN
# 14  5.760762e+09    1.163319
# 22  6.439688e+09    1.136596
# 26  6.473056e+08    1.199271

# %% [markdown]
# Dropping Rows with NaN Values in one or more GDP column

# %%
df = df.drop( df[df['gdp-1'].isna() | (df['gdp'].isna()) | (df['gdp+1'].isna()) | (df['gdp+2'].isna()) | (df['gdp+3'].isna())].index )
df.shape[0]
# Out:
# 7149

# %% [markdown]
# Combining multiple disaster from the same year and country into one column

# %%
# ToDO FoR LATER

# %% [markdown]
# ## Machine Learning

# %%
df_ml = df[ml_features + ['gdp_change']]
df_ml.head()
# Out:
#                  type           group  total_deaths  total_affected  \
# 8               Storm  Meteorological           7.0          1171.0
# 14         Earthquake     Geophysical          47.0           300.0
# 22              Storm  Meteorological       22000.0       1000000.0
# 26  Volcanic activity     Geophysical          15.0          5200.0
# 38              Storm  Meteorological         300.0           800.0
#
#     gdp_change
# 8     1.418416
# 14    1.163319
# 22    1.136596
# 26    1.199271
# 38    1.220549

# %% [markdown]
# ### Categorical Data

# %%
df_ml['type'].unique()
# Out:
# array(['Storm', 'Earthquake', 'Volcanic activity', 'Flood', 'Landslide',
#        'Epidemic', 'Wildfire', 'Mass movement (dry)',
#        'Extreme temperature ', 'Drought', 'Animal accident'], dtype=object)

# %%
df_ml['group'].unique()
# Out:
# array(['Meteorological', 'Geophysical', 'Hydrological', 'Biological',
#        'Climatological'], dtype=object)

# %%
one_hot_encoded_data = pd.get_dummies(df_ml, columns = ['type','group'])
one_hot_encoded_data
# Out:
#        total_deaths  total_affected  gdp_change  type_Animal accident  \
# 8               7.0          1171.0    1.418416                     0
# 14             47.0           300.0    1.163319                     0
# 22          22000.0       1000000.0    1.136596                     0
# 26             15.0          5200.0    1.199271                     0
# 38            300.0           800.0    1.220549                     0
# ...             ...             ...         ...                   ...
# 13693          10.0         50000.0    0.765751                     0
# 13695          11.0        500052.0    0.765751                     0
# 13699          12.0         11000.0    0.954276                     0
# 13700           3.0        100000.0    1.150856                     0
# 13702           1.0         10000.0    1.150856                     0
#
#        type_Drought  type_Earthquake  type_Epidemic  \
# 8                 0                0              0
# 14                0                1              0
# 22                0                0              0
# 26                0                0              0
# 38                0                0              0
# ...             ...              ...            ...
# 13693             0                0              0
# 13695             0                0              0
# 13699             0                0              0
# 13700             0                0              0
# 13702             0                0              0
#
#        type_Extreme temperature   type_Flood  type_Landslide  \
# 8                              0           0               0
# 14                             0           0               0
# 22                             0           0               0
# 26                             0           0               0
# 38                             0           0               0
# ...                          ...         ...             ...
# 13693                          0           1               0
# 13695                          0           1               0
# 13699                          0           0               0
# 13700                          0           0               0
# 13702                          0           0               0
#
#        type_Mass movement (dry)  type_Storm  type_Volcanic activity  \
# 8                             0           1                       0
# 14                            0           0                       0
# 22                            0           1                       0
# 26                            0           0                       1
# 38                            0           1                       0
# ...                         ...         ...                     ...
# 13693                         0           0                       0
# 13695                         0           0                       0
# 13699                         0           0                       0
# 13700                         0           1                       0
# 13702                         0           1                       0
#
#        type_Wildfire  group_Biological  group_Climatological  \
# 8                  0                 0                     0
# 14                 0                 0                     0
# 22                 0                 0                     0
# 26                 0                 0                     0
# 38                 0                 0                     0
# ...              ...               ...                   ...
# 13693              0                 0                     0
# 13695              0                 0                     0
# 13699              1                 0                     1
# 13700              0                 0                     0
# 13702              0                 0                     0
#
#        group_Geophysical  group_Hydrological  group_Meteorological
# 8                      0                   0                     1
# 14                     1                   0                     0
# 22                     0                   0                     1
# 26                     1                   0                     0
# 38                     0                   0                     1
# ...                  ...                 ...                   ...
# 13693                  0                   1                     0
# 13695                  0                   1                     0
# 13699                  0                   0                     0
# 13700                  0                   0                     1
# 13702                  0                   0                     1
#
# [7149 rows x 19 columns]

# %% [markdown]
# ### Splitting Data

# %%
X = one_hot_encoded_data.drop('gdp_change', axis=1)
y = one_hot_encoded_data['gdp_change']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model = model.fit(X_train, y_train)

# %%
from sklearn.metrics import mean_absolute_error

y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

print(f'The models mean absolute error when predicting the gdp change after a natural disaster is {mae.round(4)*100}%')
# Out:
# The models mean absolute error when predicting the gdp change after a natural disaster is 18.87%

# %% [markdown]
# ###
